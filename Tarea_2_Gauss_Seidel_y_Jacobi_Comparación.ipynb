# %%
#Tarea 2 Comparacion Gauss Seidel y Jacobi
#Metodo Gauss Seidel

"""Observaciones: Se pudo apreciar que los puntos de iteracion en la grafica de Jacobi son los mismos con respecto
 a (x,w) y (y,z), mientras que en Gauss Seidel, los puntos varian un poco, ya que en las sustituciones se toman 
 los valores mas recientes obtenidos, y en Jacobi solo se utilizan en las sustituciones los valores anteriores obtenidos."""

import matplotlib.pyplot as plt
import math
def Gauss():
  x1=[0]
  x=0
  y1=[0]
  y=0
  z1=[0]
  z=0
  w1=[0]
  w=0
  limit=0

  def x2(y):
    return  0.25+(0.25*y)
  def y2(x,z):
    return  0.25+(0.25*x)+(0.25*z)
  def z2(y,w):
    return  0.25+(0.25*y)+(0.25*w)
  def w2(z):
    return  0.25+(0.25*z)

  while(limit <10):
    
    x = x2(y)
    x1.append(x)
    y = y2(x,z)
    y1.append(y)
    z = z2(y,w)
    z1.append(z)
    w = w2(z)
    w1.append(w)
    limit+=1
  
  for x in x1:
      print("Iteraciones X: ", x)
  for y in y1:
      print("Iteraciones y: ", y)
  for z in z1:
      print("Iteraciones z: ", z)
  for w in w1:
      print("Iteraciones w: ", w)

  plt.plot(x1, label="x")
  plt.plot(y1, label="y")
  plt.plot(z1, label="z")
  plt.plot(w1, label="w")
  plt.legend()
  plt.show()

Gauss()
# Out:
# Iteraciones X:  0
# Iteraciones X:  0.25
# Iteraciones X:  0.328125
# Iteraciones X:  0.353515625
# Iteraciones X:  0.36187744140625
# Iteraciones X:  0.3633460998535156
# Iteraciones X:  0.363588809967041
# Iteraciones X:  0.3636285811662674
# Iteraciones X:  0.3636350901797414
# Iteraciones X:  0.3636361552635208
# Iteraciones X:  0.36363632954089553
# Iteraciones y:  0
# Iteraciones y:  0.3125
# Iteraciones y:  0.4140625
# Iteraciones y:  0.447509765625
# Iteraciones y:  0.4533843994140625
# Iteraciones y:  0.45435523986816406
# Iteraciones y:  0.4545143246650696
# Iteraciones y:  0.45454036071896553
# Iteraciones y:  0.4545446210540831
# Iteraciones y:  0.4545453181635821
# Iteraciones y:  0.45454543222967914
# Iteraciones z:  0
# Iteraciones z:  0.328125
# Iteraciones z:  0.4365234375
# Iteraciones z:  0.45166015625
# Iteraciones z:  0.4540748596191406
# Iteraciones z:  0.4544684886932373
# Iteraciones z:  0.4545328617095947
# Iteraciones z:  0.45454339403659105
# ...

# %%
#Metodo Jacobi

import matplotlib.pyplot as plt
import math
def sistemaEc():
  x1=[0]
  x=0
  y1=[0]
  y=0
  z1=[0]
  z=0
  w1=[0]
  w=0
  limit=0

  def x2(y):
    return  0.25+(0.25*y)
  def y2(x,z):
    return  0.25+(0.25*x)+(0.25*z)
  def z2(y,w):
    return  0.25+(0.25*y)+(0.25*w)
  def w2(z):
    return  0.25+(0.25*z)

  while(limit <10):
    
    x_1 = x2(y)
    x1.append(x_1)
    y_2 = y2(x , z)
    y1.append(y_2)
    z_3 = z2(y, w)
    z1.append(z_3)
    w_4 = w2(z)
    w1.append(w_4)
    x = x_1
    y = y_2
    z = z_3
    w = w_4
    limit+=1
  
  for x in x1:
      print("Iteraciones X: ", x)
  for y in y1:
      print("Iteraciones y: ", y)
  for z in z1:
      print("Iteraciones z: ", z)
  for w in w1:
      print("Iteraciones w: ", w)

  plt.plot(x1, label="x")
  plt.plot(y1, label="y")
  plt.plot(z1, label="z")
  plt.plot(w1, label="w")
  plt.legend()
  plt.show()

sistemaEc()
# Out:
# Iteraciones X:  0
# Iteraciones X:  0.25
# Iteraciones X:  0.3125
# Iteraciones X:  0.34375
# Iteraciones X:  0.35546875
# Iteraciones X:  0.3603515625
# Iteraciones X:  0.3623046875
# Iteraciones X:  0.36309814453125
# Iteraciones X:  0.3634185791015625
# Iteraciones X:  0.36354827880859375
# Iteraciones X:  0.3636007308959961
# Iteraciones y:  0
# Iteraciones y:  0.25
# Iteraciones y:  0.375
# Iteraciones y:  0.421875
# Iteraciones y:  0.44140625
# Iteraciones y:  0.44921875
# Iteraciones y:  0.452392578125
# Iteraciones y:  0.45367431640625
# Iteraciones y:  0.454193115234375
# Iteraciones y:  0.4544029235839844
# Iteraciones y:  0.45448780059814453
# Iteraciones z:  0
# Iteraciones z:  0.25
# Iteraciones z:  0.375
# Iteraciones z:  0.421875
# Iteraciones z:  0.44140625
# Iteraciones z:  0.44921875
# Iteraciones z:  0.452392578125
# Iteraciones z:  0.45367431640625
# Iteraciones z:  0.454193115234375
# Iteraciones z:  0.4544029235839844
# Iteraciones z:  0.45448780059814453
# ...
